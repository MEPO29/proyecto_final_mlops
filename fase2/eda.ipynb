# %%
import pandas as pd

# %%
data = pd.read_csv('freshmarket_dataset.csv')

# %%
data.columns
# Out:
# Index(['fecha_pedido', 'dia_semana', 'mes', 'dia_mes', 'hora_pedido',
#        'es_fin_semana', 'es_festivo', 'cliente_id', 'segmento_cliente',
#        'compras_previas', 'ticket_promedio_historico',
#        'dias_desde_ultima_compra', 'zona_entrega', 'num_items_carrito',
#        'incluye_perecederos', 'valor_carrito', 'tipo_entrega',
#        'nivel_inventario_general', 'productos_agotados', 'tiempo_carga_sitio',
#        'hay_promocion', 'descuento_aplicado', 'canal_adquisicion', 'clima',
#        'temperatura', 'compra_exitosa'],
#       dtype='object')

# %%
data['segmento_cliente'].value_counts()
# Out:
# segmento_cliente
# Regular     4505
# Nuevo       2507
# VIP         1985
# Inactivo    1003
# Name: count, dtype: int64

# %%
data[data['dias_desde_ultima_compra']!= 999]['dias_desde_ultima_compra'].describe()
# Out:
# count    7493.000000
# mean       44.737488
# std        25.970153
# min         1.000000
# 25%        22.000000
# 50%        44.000000
# 75%        68.000000
# max        89.000000
# Name: dias_desde_ultima_compra, dtype: float64

# %%
data['zona_entrega'].value_counts()
# Out:
# zona_entrega
# Zona 10              2507
# Zona 15              2026
# Villa Nueva          1516
# Mixco                1497
# Zona 1               1485
# San Miguel Petapa     969
# Name: count, dtype: int64

# %%
data['incluye_perecederos'].value_counts()
# Out:
# incluye_perecederos
# 1    7944
# 0    2056
# Name: count, dtype: int64

# %%
data['valor_carrito'].describe()
# Out:
# count    10000.000000
# mean        61.821566
# std         42.669223
# min          2.000000
# 25%         27.397500
# 50%         53.100000
# 75%         88.895000
# max        191.850000
# Name: valor_carrito, dtype: float64

# %%
data['nivel_inventario_general'].describe()
# Out:
# count    10000.000000
# mean        60.601456
# std         20.527245
# min          0.000000
# 25%         46.437500
# 50%         60.835000
# 75%         75.182500
# max        100.000000
# Name: nivel_inventario_general, dtype: float64

# %%
data['productos_agotados'].describe()
# Out:
# count    10000.000000
# mean         8.074200
# std          6.735461
# min          0.000000
# 25%          3.000000
# 50%          6.000000
# 75%         12.000000
# max         29.000000
# Name: productos_agotados, dtype: float64

# %%
data['tipo_entrega'].value_counts()
# Out:
# tipo_entrega
# Mismo día        5022
# Día siguiente    3486
# Programada       1492
# Name: count, dtype: int64
